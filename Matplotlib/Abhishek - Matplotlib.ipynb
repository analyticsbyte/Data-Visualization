# %%
import matplotlib.pyplot as plt

# %%
# %matplotlib inline

# %%
import numpy as np
x = np.linspace(0,5,11)
y = x**2

# %%
x
# Out:
# array([0. , 0.5, 1. , 1.5, 2. , 2.5, 3. , 3.5, 4. , 4.5, 5. ])

# %%
y
# Out:
# array([ 0.  ,  0.25,  1.  ,  2.25,  4.  ,  6.25,  9.  , 12.25, 16.  ,
#        20.25, 25.  ])

# %%
plt.plot(x,y,'r')
plt.xlabel('X Axis')
plt.ylabel('Y Axis')
plt.title('Sample Graph')
plt.show()

# %%
plt.subplot(1,2,1)
plt.plot(x,y,'r--')

plt.subplot (1,2,2)
plt.plot(y,x,'b*-')

# %% [markdown]
# ## Object Oriented Method

# %%
fig = plt.figure()

axes = fig.add_axes([0.1,0.1,0.7,0.7])

axes.plot(x,y,'b')
axes.set_xlabel('X Axis')
axes.set_ylabel('Y Axis')
axes.set_title('Sample Graph')
# Out:
# Text(0.5,1,'Sample Graph')

# %%
fig = plt.figure()

axes1 = fig.add_axes([0.1,0.1,0.8,0.8])
axes2 = fig.add_axes([0.2,0.5, 0.4, 0.3])

axes1.plot(x,y,'b')
axes1.set_xlabel('X Label 1')
axes1.set_ylabel('Y Label 1')
axes1.set_title('Axes 1 Title')

axes2.plot(y,x,'r')
axes2.set_xlabel('X Label 2')
axes2.set_ylabel('Y Label 2')
axes2.set_title('Axes 2 Title')
# Out:
# Text(0.5,1,'Axes 2 Title')

# %%
fig, axes = plt.subplots()

axes.plot(x,y,'r')
axes.set_xlabel('X axis')
axes.set_ylabel('Y axis')
axes.set_title('Sample Subplot ')
# Out:
# Text(0.5,1,'Sample Subplot ')

# %%
fig, axes = plt.subplots(nrows=1, ncols=2)

axes[0].plot(x,y,'r')
axes[0].set_title('First Plot')

axes[1].plot(y,x,'b')
axes[1].set_title('Second Plot')
# Out:
# Text(0.5,1,'Second Plot')

# %%
axes
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x1a1e001828>,
#        <matplotlib.axes._subplots.AxesSubplot object at 0x1a1d27b358>],
#       dtype=object)
